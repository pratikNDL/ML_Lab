# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['Species'] = data['Species'].replace({'Iris-setosa':1, 'Iris-versicolor':2, 'Iris-virginica':3})
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        3
# 146  147            6.3           2.5            5.0           1.9        3
# 147  148            6.5           3.0            5.2           2.0        3
# 148  149            6.2           3.4            5.4           2.3        3
# 149  150            5.9           3.0            5.1           1.8        3
#
# [150 rows x 6 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']], data['Species'], train_size = 0.2)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 87             6.3           2.3            4.4           1.3
# 94             5.6           2.7            4.2           1.3
# 9              4.9           3.1            1.5           0.1
# 95             5.7           3.0            4.2           1.2
# 21             5.1           3.7            1.5           0.4
# 83             6.0           2.7            5.1           1.6
# 11             4.8           3.4            1.6           0.2
# 27             5.2           3.5            1.5           0.2
# 30             4.8           3.1            1.6           0.2
# 120            6.9           3.2            5.7           2.3
# 108            6.7           2.5            5.8           1.8
# 102            7.1           3.0            5.9           2.1
# 126            6.2           2.8            4.8           1.8
# 17             5.1           3.5            1.4           0.3
# 45             4.8           3.0            1.4           0.3
# 4              5.0           3.6            1.4           0.2
# 29             4.7           3.2            1.6           0.2
# 0              5.1           3.5            1.4           0.2
# 50             7.0           3.2            4.7           1.4
# 46             5.1           3.8            1.6           0.2
# 92             5.8           2.6            4.0           1.2
# 107            7.3           2.9            6.3           1.8
# 31             5.4           3.4            1.5           0.4
# 97             6.2           2.9            4.3           1.3
# 85             6.0           3.4            4.5           1.6
# 59             5.2           2.7            3.9           1.4
# 23             5.1           3.3            1.7           0.5
# 15             5.7           4.4            1.5           0.4
# 71             6.1           2.8            4.0           1.3
# 112            6.8           3.0            5.5           2.1

# %%
Y_train
# Out:
# 87     2
# 94     2
# 9      1
# 95     2
# 21     1
# 83     2
# 11     1
# 27     1
# 30     1
# 120    3
# 108    3
# 102    3
# 126    3
# 17     1
# 45     1
# 4      1
# 29     1
# 0      1
# 50     2
# 46     1
# 92     2
# 107    3
# 31     1
# 97     2
# 85     2
# 59     2
# 23     1
# 15     1
# 71     2
# 112    3
# Name: Species, dtype: int64

# %%
from sklearn import linear_model
mymodel = linear_model.LogisticRegression(max_iter=120)
mymodel.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=120)

# %%
mymodel.predict(X_test)
# Out:
# array([1, 2, 3, 2, 3, 2, 1, 2, 1, 3, 2, 1, 2, 3, 1, 2, 2, 1, 2, 3, 2, 2,
#        1, 3, 1, 2, 2, 2, 2, 2, 1, 3, 2, 2, 2, 3, 1, 2, 1, 3, 1, 1, 2, 2,
#        1, 1, 1, 3, 2, 1, 2, 2, 3, 2, 3, 2, 3, 2, 3, 3, 1, 2, 2, 3, 1, 2,
#        2, 2, 1, 1, 1, 3, 1, 2, 1, 2, 3, 3, 2, 1, 1, 2, 3, 3, 2, 3, 2, 3,
#        2, 1, 2, 3, 2, 1, 1, 3, 1, 3, 2, 3, 2, 1, 3, 1, 2, 2, 1, 1, 2, 2,
#        1, 2, 2, 2, 3, 2, 3, 3, 1, 2])

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 49             5.0           3.3            1.4           0.2
# 146            6.3           2.5            5.0           1.9
# 128            6.4           2.8            5.6           2.1
# 78             6.0           2.9            4.5           1.5
# 114            5.8           2.8            5.1           2.4
# ..             ...           ...            ...           ...
# 75             6.6           3.0            4.4           1.4
# 109            7.2           3.6            6.1           2.5
# 144            6.7           3.3            5.7           2.5
# 12             4.8           3.0            1.4           0.1
# 121            5.6           2.8            4.9           2.0
#
# [120 rows x 4 columns]

# %%
mymodel.score(X_test, Y_test)
# Out:
# 0.8916666666666667

# %%
predicted_output = mymodel.predict(X_test)
predicted_output
# Out:
# array([1, 2, 3, 2, 3, 2, 1, 2, 1, 3, 2, 1, 2, 3, 1, 2, 2, 1, 2, 3, 2, 2,
#        1, 3, 1, 2, 2, 2, 2, 2, 1, 3, 2, 2, 2, 3, 1, 2, 1, 3, 1, 1, 2, 2,
#        1, 1, 1, 3, 2, 1, 2, 2, 3, 2, 3, 2, 3, 2, 3, 3, 1, 2, 2, 3, 1, 2,
#        2, 2, 1, 1, 1, 3, 1, 2, 1, 2, 3, 3, 2, 1, 1, 2, 3, 3, 2, 3, 2, 3,
#        2, 1, 2, 3, 2, 1, 1, 3, 1, 3, 2, 3, 2, 1, 3, 1, 2, 2, 1, 1, 2, 2,
#        1, 2, 2, 2, 3, 2, 3, 3, 1, 2])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, predicted_output)
cm
# Out:
# array([[36,  0,  0],
#        [ 0, 40,  0],
#        [ 0, 13, 31]])

# %%
import seaborn as sn
from matplotlib import pyplot as plt
plt.figure(figsize = (5,4))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth or Actual Value')
# Out:
# Text(33.22222222222222, 0.5, 'Truth or Actual Value')
